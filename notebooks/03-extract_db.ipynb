# %%
from getpass import getpass
from mysql.connector import connect, Error

import pandas as pd

# %%
query = "SELECT * FROM Standard_Question_Info"

# %%
try:
    with connect(database='plan_benefit_data', 
                 user='andrey', 
                 password='lFog0FCMvzktuox', 
                 host='50.116.37.183', 
                 port='3306') as connection:
        print(connection)
        
        df = pd.read_sql(query, connection)
except Error as e:
    print(e)
# Out:
# ...
# /home/andrey/roonyx_projects/question-matching/.env/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df
# Out:
#       id                                      question_id       client_id  \
# 0      2                                             None  Aetna_Medicare
# 1      3                                             None  Aetna_Medicare
# 2      5                                             None  Aetna_Medicare
# 3      6                                             None  Aetna_Medicare
# 4      7                                             None  Aetna_Medicare
# ..   ...                                              ...             ...
# 298  301               benefit_term-standard_cost-sharing  Aetna_Medicare
# 299  302                        benefit_term-step_therapy  Aetna_Medicare
# 300  303  benefit_term-supplemental_security_income_(SSL)  Aetna_Medicare
# 301  304            benefit_term-urgently_needed_services  Aetna_Medicare
# 302  305                benefit_term-prior_authorizations  Aetna_Medicare
#
#             campaign_id question_category         question_subcategory  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    303 non-null    int64
#  1   question_id           295 non-null    object
#  2   client_id             303 non-null    object
#  3   campaign_id           303 non-null    object
#  4   question_category     303 non-null    object
#  5   question_subcategory  303 non-null    object
#  6   question_description  303 non-null    object
#  7   benefit_cat1_cd       232 non-null    object
#  8   benefit_cat2_cd       232 non-null    object
#  9   message_method        10 non-null     object
#  10  template_phrase       10 non-null     object
#  11  created_by            0 non-null      object
#  12  created_date          0 non-null      object
# dtypes: int64(1), object(12)
# memory usage: 30.9+ KB

# %%
df.to_csv('../data/raw/db_data.csv', index=False)
